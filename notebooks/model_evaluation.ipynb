# %%
# %matplotlib inline

# %% [markdown]
# Loading from my custom function

# %%
from spreaddiagram import spread_diagram, bias, root_mean_square_error

# %%
data = pd.read_csv("../data/vmm_flowdata.csv", parse_dates=True, index_col=0).dropna()

# %%
data.head()
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
fig, ax = plt.subplots(figsize=(8, 8))

spread_diagram(ax, data["L06_347"].values, 
               data["LS06_347"].values, 
               infobox = True)
# ax....

# %% [markdown]
# http://colorbrewer2.org/#type=sequential&scheme=BuGn&n=3

# %%
fig, ax = plt.subplots(figsize=(8, 8))
spread_diagram(ax, data["L06_347"].values, 
               data["LS06_347"].values, 
               infobox = False, 
               color='#666699', edgecolor=None)

# %% [markdown]
# # Command line version

# %%
# %%file puretest.py

import sys


def main(argv=None):
    print(argv[0], argv[1])
    

if __name__ == "__main__":
    sys.exit(main(sys.argv))
# Out:
# Writing puretest.py

# %%
# !python puretest.py argument1
# Out:
# puretest.py argument1

# %%
import datetime
datetime.date.today().strftime("%Y%m%d")
# Out:
# '20161221'
